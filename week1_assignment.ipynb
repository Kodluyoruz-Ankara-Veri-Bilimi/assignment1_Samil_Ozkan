# %%
class Information():
    
    def __init(self, ...):
        self.data=data
        
    def info(self):
        print(self.data.info())
    
    def describe(self):
        print(self.data.describe())
        

        
class Visualizaton():
    
    def __init(self,...):
        pass
        
    def histo():
        pass
    
    def scatt():
        pass
    
    def box():
        pass
    
    def heatmap():
        pass
    
    def piechart():
        pass
    
 

 class Preprocess():
    
    def __init(self,...):
        pass
    
    def cleaning(self):
        pass
        
    def fillna(self):
        pass
    
    def dropna(self):
        pass
    
    def label_encoder(self):
        pass
    
    def dummy_encoding(self):
        pass
    
    def feature_scaling(self):
        pass
    
    def outlies(self):
        pass
    
class Classification(self):
    def __init__(self):
        
    def KNeighborsRegression(self):
        pass
    
    def RandomForestRegressor(self):
        pass
    
    def DecisonTreeClassifier(self):
        pass

    
class GridSearchCV():
    def __init__(self):
        
    def show_result(self):
        pass
    
    def predplot(self):
        pass
    
    def confusion(self):
        pass
